# %%
from msilib.schema import File
import time
import pandas as pd
import re
import openpyxl
import datetime
import tkinter as tk
from tkinter import TOP, ttk
from tkinter import filedialog as fd
from tkinter.messagebox import showinfo
from tkinter.filedialog import asksaveasfile
import PySimpleGUI as sg



def main(): 
    print("Select the current allocations File:")
    allocf = FilePrompt()
    df_ea = pd.read_excel(allocf)
    df_ea = df_ea.reset_index()
    
    print(df_ea)


def FilePrompt():
    root = tk.Tk()
    root.title('Tkinter Open File Dialog')
    root.resizable(False, False)
    root.geometry('300x150')
    root.withdraw()


    filename = fd.askopenfilename()

    return filename
    
def save_dataframe(df, sl):
    file_path = fd.asksaveasfilename(defaultextension=".xlsx", filetypes=[("Excel files", "*.xlsx"), ("All files", "*.*")])
    
    if file_path:
        try:
            # Assuming df is your DataFrame
            df.to_excel(file_path, index=False)
            sl.config(text=f"Saved as {file_path}")
        except Exception as e:
            sl.config(text=f"Error: {str(e)}")


if __name__ == "__main__":
    main()
# Out:
# Select the current allocations File:
#     index   #  Entity Company Code               Employee Name  File Number  \
# 0       0   1     2.0          ML7               Dam,Phuong My        207.0
# 1       1   2     2.0          ML7                 Lee,My Dung         77.0
# 2       2   3     2.0          ML7              Vaccari,Sergio         83.0
# 3       3   4     2.0          ML7               Lagano,Lauren        367.0
# 4       4   5     2.0          ML7                         ALL          NaN
# 5       5   6     2.0          ML7                         ALL          NaN
# 6       6   7     2.0          ML7                         ALL          NaN
# 7       7   8     2.0          ML7                         ALL          NaN
# 8       8   9     2.0          ML7                         ALL          NaN
# 9       9  10     2.0          ML7                         ALL          NaN
# 10     10  11     2.0          ML7      Spivey,Allison Michele         81.0
# 11     11  12     2.0          ML7                 Dungy,Ellen        230.0
# 12     12  13     2.0          ML7               Gardner,Jason         74.0
# 13     13  14     2.0          ML7    Accuosti-Vaccaro, Shiloh         64.0
# 14     14  15     2.0          ML7            Hemingway,Jeremy        299.0
# 15     15  16     2.0          ML7                 Sikder,Mark        577.0
# 16     16  17     7.0          22J                Krall,Audrey         53.0
# 17     17  18     7.0          22J                Dean,Ursulla         52.0
# 18     18  19     7.0          22J                   Tran, Nam         54.0
# 19     19  20     7.0          22J        Buckmaster,Roxanne M         51.0
# 20     20  21     7.0          22J           Anders,Amanda Lee        244.0
# 21     21  22     7.0          22J                Conant,Julia         77.0
# 22     22  23     7.0          22J  David, Alexandria Allane S          NaN
# 23     23  24     8.0          362                 Bell, Allie         53.0
# 24     24  25     8.0          362              Klatsky, Peter         54.0
# 25     25  26     8.0          362                 Perez,Viola         56.0
# 26     26  27     NaN          NaN                         NaN          NaN
# 27     27  28     NaN          NaN                         NaN          NaN
# 28     28  29     NaN          NaN                         NaN          NaN
# 29     29  30     NaN          NaN                         NaN          NaN
#
#    POSITION ID        Department Long Descr SUB_DEPARTMENT LOCATION    HQ  \
# 0    ML7000207          Clinical Operations      Operating  SFM MSO  0.00
# 1    ML7000077          Clinical Operations      Operating  SFM MSO  0.00
# 2    ML7000083                          Lab            Lab       SF  0.00
# 3    ML7000367          Clinical Operations      Operating  SFM MSO  0.50
# 4          NaN              Receptionist HQ      Operating  SFM MSO  0.00
# 5          NaN              Medical Records      Operating  SFM MSO  0.00
# 6          NaN                 Call Center       Operating  SFM MSO  0.00
# 7          NaN          Financial Counselor      Operating  SFM MSO  0.00
# 8                       Clinical Operations      Operating  SFM MSO  0.00
# 9          NaN                Revenue Cycle      Operating  SFM MSO  0.00
# 10   ML7000081                    Marketing             HQ  SFM MSO  0.00
# 11   ML7000230          Clinical Operations      Operating  SFM MSO  0.00
# 12   ML7000074                   Facilities      Operating  SFM MSO  0.00
# 13   ML7000064                    Marketing             HQ  SFM MSO  0.00
# 14   ML7000299          Clinical Operations      Operating  SFM MSO  0.00
# 15   ML7000577          Clinical Operations      Operating  SFM MSO  0.00
# 16   22J000053                        NP/PA       Clinical       SF  0.00
# 17   22J000052                        NP/PA       Clinical       SF  0.00
# 18   22J000054  Corporate Executive Partner             MD       SF  0.10
# 19   22J000051          Clinical Operations             HQ  SFM MSO  0.00
# 20   22J000244                           RN       Clinical       SF  0.00
# 21   22J000077                Medical Staff       Clinical       SF  0.00
# 22         NaN                       RN-ASC            ASC      OAK  0.00
# 23   362000053          Clinical Operations      Operating  SFM MSO  0.00
# 24   362000054                   Physicians             MD      NYC  0.25
# 25   362000056          Clinical Operations      Operating  SFM MSO  0.00
# 26         NaN                          NaN            NaN      NaN   NaN
# 27         NaN                          NaN            NaN      NaN   NaN
# 28         NaN                          NaN            NaN      NaN   NaN
# 29         NaN                          NaN            NaN      NaN   NaN
#
#     Nest     SF    OAK     SV   NYC  PDX  Unnamed: 16
# 0   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 1   0.05  0.250  0.200  0.300  0.00  0.2          1.0
# 2   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 3   0.50  0.000  0.000  0.000  0.00  0.0          1.0
# 4   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 5   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 6   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 7   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 8   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 9   0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 10  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 11  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 12  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 13  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 14  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 15  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 16  0.00  0.750  0.125  0.125  0.00  0.0          1.0
# 17  0.00  0.125  0.125  0.750  0.00  0.0          1.0
# 18  0.00  0.590  0.000  0.310  0.00  0.0          1.0
# 19  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 20  0.25  0.750  0.000  0.000  0.00  0.0          1.0
# 21  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 22  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 23  0.00  0.450  0.200  0.150  0.20  0.0          1.0
# 24  0.00  0.000  0.000  0.000  0.75  0.0          1.0
# 25  0.00  0.100  0.050  0.050  0.80  0.0          1.0
# 26   NaN    NaN    NaN    NaN   NaN  NaN          NaN
# 27   NaN    NaN    NaN    NaN   NaN  NaN          NaN
# 28   NaN    NaN    NaN    NaN   NaN  NaN          NaN
# 29   NaN    NaN    NaN    NaN   NaN  NaN          NaN

# %%
print(df_ea)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 print(df_ea)
#
# NameError: name 'df_ea' is not defined
